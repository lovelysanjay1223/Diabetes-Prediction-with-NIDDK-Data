# %% [markdown]
# ### Healthcare PGP
#
# #### DESCRIPTION
#
# #### Problem Statement
# NIDDK (National Institute of Diabetes and Digestive and Kidney Diseases) research creates knowledge about and treatments for the most chronic, costly, and consequential diseases.
#
# The dataset used in this project is originally from NIDDK. The objective is to predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset.
#
# Build a model to accurately predict whether the patients in the dataset have diabetes or not.
#
# ##### Dataset Description
# The datasets consists of several medical predictor variables and one target variable (Outcome). Predictor variables includes the number of pregnancies the patient has had, their BMI, insulin level, age, and more.
#
#
#
# ##### Variables	             ##### Description
# 1. Pregnancies:	   Number of times pregnant
#
# 2. Glucose:	       Plasma glucose concentration in an oral glucose tolerance test
#
# 3. BloodPressure:	Diastolic blood pressure (mm Hg)
#
# 4. SkinThickness:	Triceps skinfold thickness (mm)
#
# 5. Insulin:	     Two hour serum insulin
#
# 6. BMI:	         Body Mass Index
#
# 7. DiabetesPedigreeFunction: 	Diabetes pedigree function
#
# 8. Age:	    Age in years
#
# 9. Outcome:	     Class variable (either 0 or 1). 268 of 768 values are 1, and the others are 0
#
# ##### Project Task: Week 1
# ##### Data Exploration:
#
# 1. Perform descriptive analysis. Understand the variables and their corresponding values. On the columns below, a value of zero does not make sense and thus indicates missing value:
#
#     • Glucose
#
#     • BloodPressure
#
#     • SkinThickness
#
#     • Insulin
#
#     • BMI
#
# 2. Visually explore these variables using histograms. Treat the missing values accordingly.
#
# 3. There are integer and float data type variables in this dataset. Create a count (frequency) plot describing the data types and the count of variables.
#
# ##### Project Task: Week 2
# ##### Data Exploration:
#
# 1. Check the balance of the data by plotting the count of outcomes by their value. Describe your findings and plan future course of action.
#
# 2. Create scatter charts between the pair of variables to understand the relationships. Describe your findings.
#
# 3. Perform correlation analysis. Visually explore it using a heat map.
#
#
#
# ##### Project Task: Week 3
# ##### Data Modeling:
#
# 1. Devise strategies for model building. It is important to decide the right validation framework. Express your thought process.
#
# 2. Apply an appropriate classification algorithm to build a model. Compare various models with the results from KNN algorithm.
#
#
#
# ##### Project Task: Week 4
#
# ##### Data Modeling:
#
# 1. Create a classification report by analyzing sensitivity, specificity, AUC (ROC curve), etc. Please be descriptive to explain what values of these parameter you have used.
#
# ##### Data Reporting:
#
# 2. Create a dashboard in tableau by choosing appropriate chart types and metrics useful for the business. The dashboard must entail the following:
#
#     a. Pie chart to describe the diabetic or non-diabetic population
#
#     b. Scatter charts between relevant variables to analyze the relationships
#
#     c. Histogram or frequency charts to analyze the distribution of the data
#
#     d. Heatmap of correlation analysis among the relevant variables
#
#     e. Create bins of these age values: 20-25, 25-30, 30-35, etc. Analyze different variables for these age brackets using a bubble chart.

# %% [markdown]
# ## Project Task: Week 1
# ### Data Exploration:
#
# 1. Perform descriptive analysis. Understand the variables and their corresponding values. On the columns below, a value of zero does not make sense and thus indicates missing value:
#
#     • Glucose
#
#     • BloodPressure
#
#     • SkinThickness
#
#     • Insulin
#
#     • BMI
#
# 2. Visually explore these variables using histograms. Treat the missing values accordingly.
#
# 3. There are integer and float data type variables in this dataset. Create a count (frequency) plot describing the data types and the count of variables.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Lovely Rajput\Desktop\Data Science Capstone\Data-Science-Capstone-Projects-master\Data-Science-Capstone-Projects-master\Project_2\Project 2\Healthcare - Diabetes/health care diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe().transpose()
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %% [markdown]
# ### To find null values in the data set

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ##### There are no null values in this DataSet

# %% [markdown]
# ### Create a count (frequency) plot describing the data types and the count of variables.

# %%
dict={}
for i in df.columns:
    dict[i]=df[i].value_counts().shape[0]
pd.DataFrame(dict,index=['Unique']).transpose()
# Out:
#                           Unique
# Pregnancies                   17
# Glucose                      136
# BloodPressure                 47
# SkinThickness                 51
# Insulin                      186
# BMI                          248
# DiabetesPedigreeFunction     517
# Age                           52
# Outcome                        2

# %% [markdown]
# ##### Checking the datatypes of all the columns in the dataset

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# ##### all the columns have numeric values so no need to encode the columns

# %% [markdown]
# ##### Visually explore variables using histograms

# %%
df.hist(figsize=(20,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Pregnancies maximum range is varing from 0.0-5.0
#
# Glucose maximum range is ranging from 75-140
#
# BloodPressure range is ranging from 60-75
#
# Skin Thickness is widely distributed from 0-40
#
# Insulin maximum amount of people having in range 0-200
#
# BMI is 20-60
#
# DiabetesPedigreeFunction is maximum between 0.0-0.6
#
# Age of maximum people is between 20-40
#
# Outcome is eithe 0 or 1

# %% [markdown]
# ## Project Task: Week 2
# ### Data Exploration:
#
# 1. Check the balance of the data by plotting the count of outcomes by their value. Describe your findings and plan future course of action.
#
# 2. Create scatter charts between the pair of variables to understand the relationships. Describe your findings.
#
# 3. Perform correlation analysis. Visually explore it using a heat map.

# %%
fig=plt.figure(figsize=(20,12))
gs=fig.add_gridspec(2,4)
ax0=fig.add_subplot(gs[0,0])
ax1=fig.add_subplot(gs[0,1])
ax2=fig.add_subplot(gs[0,2])
ax3=fig.add_subplot(gs[0,3])
ax4=fig.add_subplot(gs[1,0])
ax5=fig.add_subplot(gs[1,1])
ax6=fig.add_subplot(gs[1,2])
ax7=fig.add_subplot(gs[1,3])

sns.boxplot(df['Pregnancies'],data=df,ax=ax0)
sns.boxplot(df['Glucose'],data=df,ax=ax1)
sns.boxplot(df['BloodPressure'],data=df,ax=ax2)
sns.boxplot(df['SkinThickness'],data=df,ax=ax3)
sns.boxplot(df['Insulin'],data=df,ax=ax4)
sns.boxplot(df['BMI'],data=df,ax=ax5)
sns.boxplot(df['DiabetesPedigreeFunction'],data=df,ax=ax6)
sns.boxplot(df['Age'],data=df,ax=ax7)
# Out:
# D:\Lovely\anacondaNew\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Lovely\anacondaNew\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Lovely\anacondaNew\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
from autoviz.AutoViz_Class import AutoViz_Class
av=AutoViz_Class()
# Out:
# Imported AutoViz_Class version: 0.0.84. Call using:
#     AV = AutoViz_Class()
#     AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=0,
#                             lowess=False,chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30)
# Note: verbose=0 or 1 generates charts and displays them in your local Jupyter notebook.
#       verbose=2 does not show plot but creates them and saves them in AutoViz_Plots directory in your local machine.

# %%
dft = av.AutoViz(r'C:\Users\Lovely Rajput\Desktop\Data Science Capstone\Data-Science-Capstone-Projects-master\Data-Science-Capstone-Projects-master\Project_2\Project 2\Healthcare - Diabetes/health care diabetes.csv', 
                 dfte=df,
                 header=0, 
                 verbose=2, 
                 lowess=False,
                 chart_format="svg", 
                 max_rows_analyzed=1000, 
                 max_cols_analyzed=10)
# Out:
# Shape of your Data Set loaded: (768, 9)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
# Data Set Shape: 768 rows, 9 cols
# Data Set columns info:
# * Pregnancies: 0 nulls, 17 unique vals, most common: {1: 135, 0: 111}
# * Glucose: 0 nulls, 136 unique vals, most common: {100: 17, 99: 17}
# * BloodPressure: 0 nulls, 47 unique vals, most common: {70: 57, 74: 52}
# * SkinThickness: 0 nulls, 51 unique vals, most common: {0: 227, 32: 31}
# * Insulin: 0 nulls, 186 unique vals, most common: {0: 374, 105: 11}
# * BMI: 0 nulls, 248 unique vals, most common: {32.0: 13, 31.6: 12}
# * DiabetesPedigreeFunction: 0 nulls, 517 unique vals, most common: {0.254: 6, 0.258: 6}
# * Age: 0 nulls, 52 unique vals, most common: {22: 72, 21: 63}
# * Outcome: 0 nulls, 2 unique vals, most common: {0: 500, 1: 268}
# --------------------------------------------------------------------
# ...

# %%
Positive = df[df['Outcome']==1]
Positive.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 2            8      183             64              0        0  23.3
# 4            0      137             40             35      168  43.1
# 6            3       78             50             32       88  31.0
# 8            2      197             70             45      543  30.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 2                     0.672   32        1
# 4                     2.288   33        1
# 6                     0.248   26        1
# 8                     0.158   53        1

# %%
Positive.hist(figsize=(20,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(*, block=None)>

# %%
dict={}
for i in Positive.columns:
    dict[i]=Positive[i].value_counts().shape[0]
pd.DataFrame(dict,index=['Unique']).transpose()
# Out:
#                           Unique
# Pregnancies                   17
# Glucose                      104
# BloodPressure                 39
# SkinThickness                 43
# Insulin                       93
# BMI                          148
# DiabetesPedigreeFunction     231
# Age                           45
# Outcome                        1

# %% [markdown]
# #### Create scatter charts between the pair of variables to understand the relationships

# %%
BloodPressure = Positive['BloodPressure']
Glucose = Positive['Glucose']
SkinThickness = Positive['SkinThickness']
Insulin = Positive['Insulin']
BMI = Positive['BMI']

# %%
plt.scatter(BloodPressure, Glucose, color=['b'])
plt.xlabel('BloodPressure')
plt.ylabel('Glucose')
plt.title('BloodPressure & Glucose')
plt.show()

# %%
g =sns.scatterplot(x= "Glucose" ,y= "BloodPressure",
              hue="Outcome",
              data=df);

# %%
B =sns.scatterplot(x= "BMI" ,y= "Insulin",
              hue="Outcome",
              data=df);

# %%
S =sns.scatterplot(x= "SkinThickness" ,y= "Insulin",
              hue="Outcome",
              data=df);

# %%
### correlation matrix
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
### create correlation heat map
plt.subplots(figsize=(8,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Project Task: Week 3
# ### Data Modeling:
#
# 1. Devise strategies for model building. It is important to decide the right validation framework. Express your thought process.
#
# 2. Apply an appropriate classification algorithm to build a model. Compare various models with the results from KNN algorithm.

# %% [markdown]
# ##### Preprocessing

# %%
X=df.drop('Outcome',axis='columns')
y=df['Outcome']

# %%
print(X.shape)
print(y.shape)
# Out:
# (768, 8)
# (768,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (614,)
# (154, 8)
# (154,)

# %% [markdown]
# ##### Scaling down the columns

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# ### Models

# %% [markdown]
# #### LogisticRegression & Hypertuning

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,mean_absolute_error,mean_squared_error,r2_score,accuracy_score
Logmodel=LogisticRegression()
Logmodel.fit(X_train,y_train)
y_pred=Logmodel.predict(X_test)
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("\nConfusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("\nTesting Score:\n",Logmodel.score(X_test,y_test)*100)
print("\nMean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("\nR2 score is:\n",r2_score(y_test,y_pred))
print("\nbest params: ", Logmodel.get_params())
print('\naccuracy score: ', accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       107
#            1       0.70      0.55      0.62        47
#
#     accuracy                           0.79       154
#    macro avg       0.76      0.73      0.74       154
# weighted avg       0.78      0.79      0.78       154
#
#
# Confusion Matrix:
#  [[96 11]
#  [21 26]]
#
# Testing Score:
#  79.22077922077922
#
# Mean Squared Error:
#  0.2077922077922078
#
# R2 score is:
#  0.020083515609465197
#
# best params:  {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'auto', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
#
# accuracy score:  79.22077922077922

# %% [markdown]
# #### ROC Curves: A useful tool when predicting the probability of a binary outcome is the Receiver Operating Characteristic curve, or ROC curve. It is a plot of the false positive rate (x-axis) versus the true positive rate (y-axis) for a number of different candidate threshold values between 0.0 and 1.0. Put another way, it plots the false alarm rate versus the hit rate.
#
# ##### True Positive Rate = True Positives / (True Positives + False Negatives)
#
# The true positive rate is also referred to as sensitivity.
#
# ##### Sensitivity = True Positives / (True Positives + False Negatives)
#
# ##### False Positive Rate = False Positives / (False Positives + True Negatives)
#
# The false positive rate is also referred to as the inverted specificity.
#
# ##### Specificity = True Negatives / (True Negatives + False Positives)
#
# Where:
#
# ##### False Positive Rate = 1 - Specificity

# %%
#Preparing ROC Curve (Receiver Operating Characteristics Curve)
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

# predict probabilities
probs = Logmodel.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# generate a no skill prediction (majority class)
ns_probs = [0 for _ in range(len(y_test))]
# calculate AUC and No Skill 
ns_auc = roc_auc_score(y_test, ns_probs)
auc = roc_auc_score(y_test, probs)
print('Logistic: ROC AUC=%.3f' % auc)
print('No Skill: ROC AUC=%.3f' % (ns_auc))
# calculate roc curve
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
fpr, tpr, thresholds = roc_curve(y_test, probs)
# plot no skill
pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
# plot the roc curve for the model
pyplot.plot(fpr, tpr, marker='.',label='Logistic')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Logistic: ROC AUC=0.825
# No Skill: ROC AUC=0.500

# %% [markdown]
# #### Precision-Recall Curves: A precision-recall curve is a plot of the precision (y-axis) and the recall (x-axis) for different thresholds, much like the ROC curve.
# ##### Positive Predictive Power = True Positives / (True Positives + False Positives)
# OR
# ##### Precision = True Positives / (True Positives + False Positives)
#
# ##### Recall = True Positives / (True Positives + False Negatives)
# OR
# ##### Sensitivity = True Positives / (True Positives + False Negatives)
# Recall == Sensitivity
#
# #### There are also composite scores that attempt to summarize the precision and recall; two examples include:
#
# ##### F-Measure or F1 score: that calculates the harmonic mean of the precision and recall (harmonic mean because the precision and recall are rates).
# ##### Area Under Curve: like the AUC, summarizes the integral or an approximation of the area under the precision-recall curve.

# %%
#Precision Recall Curve for Logistic Regression

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
from matplotlib import pyplot

# predict probabilities
probs = Logmodel.predict_proba(X_test)
# keep probabilities for the positive outcome only
probs = probs[:, 1]
# predict class values
yhat = Logmodel.predict(X_test)
# calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_test, probs)
# calculate F1 score
f1 = f1_score(y_test, yhat)
# calculate precision-recall AUC
auc = auc(recall, precision)
# calculate average precision score
ap = average_precision_score(y_test, probs)
print('Logistic: f1=%.3f auc=%.3f ap=%.3f' % (f1, auc, ap))
# plot no skill
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
# plot the precision-recall curve for the model
plt.plot(recall, precision, marker='.',label='Logistic')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Logistic: f1=0.619 auc=0.724 ap=0.727

# %% [markdown]
# #### KNN & Hypertuning

# %%
from sklearn.neighbors import KNeighborsClassifier
KNNmodel=KNeighborsClassifier()
KNNmodel.fit(X_train,y_train)
from sklearn.metrics import mean_absolute_error,mean_squared_error,confusion_matrix,r2_score,accuracy_score
y_pred=KNNmodel.predict(X_test)
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("\nConfusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("\nTesting Score:\n",KNNmodel.score(X_test,y_test)*100)
print("\nMean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("\nR2 score is:\n",r2_score(y_test,y_pred))
print("\nbest params: ", KNNmodel.get_params())
print('\naccuracy score: ', accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79       107
#            1       0.51      0.51      0.51        47
#
#     accuracy                           0.70       154
#    macro avg       0.65      0.65      0.65       154
# weighted avg       0.70      0.70      0.70       154
#
#
# Confusion Matrix:
#  [[84 23]
#  [23 24]]
#
# Testing Score:
#  70.12987012987013
#
# Mean Squared Error:
#  0.2987012987012987
#
# R2 score is:
#  -0.4086299463113938
#
# best params:  {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': None, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
#
# accuracy score:  70.12987012987013

# %%
#Preparing ROC Curve (Receiver Operating Characteristics Curve)
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

# predict probabilities
KNprobs = KNNmodel.predict_proba(X_test)
# keep probabilities for the positive outcome only
KNprobs = KNprobs[:, 1]
# generate a no skill prediction (majority class)
ns_probs = [0 for _ in range(len(y_test))]
# calculate AUC and No Skill 
ns_auc = roc_auc_score(y_test, ns_probs)
auc = roc_auc_score(y_test, KNprobs)
print('KNN: ROC AUC=%.3f' % auc)
print('No Skill: ROC AUC=%.3f' % (ns_auc))
# calculate roc curve
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
fpr, tpr, thresholds = roc_curve(y_test, KNprobs)
print("True Positive Rate - {},\n False Positive Rate - {},\n Thresholds - {}".format(tpr,fpr,thresholds))
# plot no skill
pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
# plot the roc curve for the model
pyplot.plot(fpr, tpr, marker='.',label='KNN')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# KNN: ROC AUC=0.720
# No Skill: ROC AUC=0.500
# True Positive Rate - [0.         0.12765957 0.27659574 0.5106383  0.72340426 0.89361702
#  1.        ],
#  False Positive Rate - [0.         0.02803738 0.05607477 0.21495327 0.39252336 0.64485981
#  1.        ],
#  Thresholds - [2.  1.  0.8 0.6 0.4 0.2 0. ]

# %%
#Precision Recall Curve for KNN

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
from matplotlib import pyplot

# predict probabilities
KNprobs = KNNmodel.predict_proba(X_test)
# keep probabilities for the positive outcome only
KNprobs = KNprobs[:, 1]
# predict class values
yhat = KNNmodel.predict(X_test)
# calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_test, KNprobs)
# calculate F1 score
f1 = f1_score(y_test, yhat)
# calculate precision-recall AUC
auc = auc(recall, precision)
# calculate average precision score
ap = average_precision_score(y_test, KNprobs)
print('KNN: f1=%.3f auc=%.3f ap=%.3f' % (f1, auc, ap))
# plot no skill
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
# plot the precision-recall curve for the model
plt.plot(recall, precision, marker='.',label='KNN')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# KNN: f1=0.511 auc=0.555 ap=0.499

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
params={
    'n_neighbors':[1,3,5,7,9],
    'weights':['uniform', 'distance'],
    'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute']
}
model2=GridSearchCV(KNNmodel,param_grid=params,cv=10,n_jobs=None,verbose=True)
model2.fit(X_train,y_train)
y_pred=model2.predict(X_test)
print('best estimator: ',model2.best_estimator_)
print('\nbest params: ',model2.best_params_)
print('\nclassification report: ',classification_report(y_test,y_pred))
print('\nmae: ',mean_absolute_error(y_test,y_pred))
print('\nmse: ',mean_squared_error(y_test,y_pred))
print('\nr2 score: ',r2_score(y_test,y_pred))
print('\nmodel2-score: ',model2.score(X_test,y_test)*100)
print('\naccuracy score: ',accuracy_score(y_test,y_pred)*100)
# Out:
# Fitting 10 folds for each of 40 candidates, totalling 400 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# best estimator:  KNeighborsClassifier(n_neighbors=9, weights='distance')
#
# best params:  {'algorithm': 'auto', 'n_neighbors': 9, 'weights': 'distance'}
#
# classification report:                precision    recall  f1-score   support
#
#            0       0.78      0.83      0.81       107
#            1       0.55      0.47      0.51        47
#
#     accuracy                           0.72       154
#    macro avg       0.67      0.65      0.66       154
# weighted avg       0.71      0.72      0.71       154
#
#
# mae:  0.2792207792207792
#
# mse:  0.2792207792207792
#
# r2 score:  -0.3167627758997813
#
# model2-score:  72.07792207792207
#
# accuracy score:  72.07792207792207
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:    2.1s finished

# %% [markdown]
# #### Decision Tree & Hypertuning

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=6, random_state=123,criterion='entropy')

dtree.fit(X_train,y_train)
y_pred=dtree.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("\nConfusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("\nTesting Score:\n",dtree.score(X_test,y_test)*100)
print("\nMean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("\nR2 score is:\n",r2_score(y_test,y_pred))
print('\naccuracy score: ',accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82       107
#            1       0.58      0.47      0.52        47
#
#     accuracy                           0.73       154
#    macro avg       0.68      0.66      0.67       154
# weighted avg       0.72      0.73      0.73       154
#
#
# Confusion Matrix:
#  [[91 16]
#  [25 22]]
#
# Testing Score:
#  73.37662337662337
#
# Mean Squared Error:
#  0.2662337662337662
#
# R2 score is:
#  -0.2555179956253728
#
# accuracy score:  73.37662337662337

# %%
#Preparing ROC Curve (Receiver Operating Characteristics Curve)
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot

# predict probabilities
DTprobs = dtree.predict_proba(X_test)
# keep probabilities for the positive outcome only
DTprobs = DTprobs[:, 1]
# generate a no skill prediction (majority class)
ns_probs = [0 for _ in range(len(y_test))]
# calculate AUC and No Skill 
ns_auc = roc_auc_score(y_test, ns_probs)
auc = roc_auc_score(y_test, DTprobs)
print('Decision Tree: ROC AUC=%.3f' % auc)
print('No Skill: ROC AUC=%.3f' % (ns_auc))
# calculate roc curve
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
fpr, tpr, thresholds = roc_curve(y_test, DTprobs)
print("True Positive Rate - {},\n False Positive Rate - {},\n Thresholds - {}".format(tpr,fpr,thresholds))
# plot no skill
pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
# plot the roc curve for the model
pyplot.plot(fpr, tpr, marker='.',label='Decision Tree')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Decision Tree: ROC AUC=0.764
# No Skill: ROC AUC=0.500
# True Positive Rate - [0.         0.36170213 0.40425532 0.46808511 0.4893617  0.61702128
#  0.63829787 0.72340426 0.76595745 0.78723404 0.78723404 0.89361702
#  0.91489362 1.        ],
#  False Positive Rate - [0.         0.12149533 0.13084112 0.14953271 0.1682243  0.23364486
#  0.24299065 0.25233645 0.36448598 0.37383178 0.42990654 0.43925234
#  0.56074766 1.        ],
#  Thresholds - [2.         1.         0.90909091 0.63157895 0.5        0.49315068
#  0.45454545 0.44444444 0.40740741 0.4        0.11111111 0.07142857
#  0.03448276 0.        ]

# %%
#Precision Recall Curve for Decision Tree

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
from matplotlib import pyplot

# predict probabilities
DTprobs = dtree.predict_proba(X_test)
# keep probabilities for the positive outcome only
DTprobs = DTprobs[:, 1]
# predict class values
yhat = dtree.predict(X_test)
# calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_test, DTprobs)
# calculate F1 score
f1 = f1_score(y_test, yhat)
# calculate precision-recall AUC
auc = auc(recall, precision)
# calculate average precision score
ap = average_precision_score(y_test, DTprobs)
print('Decision Tree: f1=%.3f auc=%.3f ap=%.3f' % (f1, auc, ap))
# plot no skill
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
# plot the precision-recall curve for the model
plt.plot(recall, precision, marker='.',label='Decision Tree')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Decision Tree: f1=0.518 auc=0.606 ap=0.521

# %% [markdown]
# #### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestClassifier
RFmodel=RandomForestClassifier(n_estimators=100,criterion='entropy',random_state=0)
RFmodel.fit(X_train,y_train)
y_pred=RFmodel.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("\nConfusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("\nTesting Score:\n",RFmodel.score(X_test,y_test)*100)
print("\nMean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("\nR2 score is:\n",r2_score(y_test,y_pred))
print("\nbest params: ",RFmodel.get_params())
print('\naccuracy score',accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82       107
#            1       0.60      0.60      0.60        47
#
#     accuracy                           0.75       154
#    macro avg       0.71      0.71      0.71       154
# weighted avg       0.75      0.75      0.75       154
#
#
# Confusion Matrix:
#  [[88 19]
#  [19 28]]
#
# Testing Score:
#  75.32467532467533
#
# Mean Squared Error:
#  0.24675324675324675
#
# R2 score is:
#  -0.16365082521376006
#
# best params:  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 0, 'verbose': 0, 'warm_start': False}
#
# ...

# %%
#Precision Recall Curve for Random Forest

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
from matplotlib import pyplot

# predict probabilities
RFprobs = RFmodel.predict_proba(X_test)
# keep probabilities for the positive outcome only
RFprobs = RFprobs[:, 1]
# predict class values
yhat = RFmodel.predict(X_test)
# calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_test, RFprobs)
# calculate F1 score
f1 = f1_score(y_test, yhat)
# calculate precision-recall AUC
auc = auc(recall, precision)
# calculate average precision score
ap = average_precision_score(y_test, RFprobs)
print('Random Forest: f1=%.3f auc=%.3f ap=%.3f' % (f1, auc, ap))
# plot no skill
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
# plot the precision-recall curve for the model
plt.plot(recall, precision, marker='.',label='Random Forest')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Random Forest: f1=0.596 auc=0.662 ap=0.659

# %% [markdown]
# #### Support Vector Classifier

# %%
from sklearn.svm import SVC 
SVmodel = SVC(kernel='rbf',
           gamma='auto',probability=True)
SVmodel.fit(X_train,y_train)
y_pred=SVmodel.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("\nConfusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("\nTesting Score:\n",SVmodel.score(X_test,y_test)*100)
print("\nMean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("\nR2 score is:\n",r2_score(y_test,y_pred))
print("\nbest params: ",SVmodel.get_params())
print('\naccuracy score',accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85       107
#            1       0.69      0.53      0.60        47
#
#     accuracy                           0.79       154
#    macro avg       0.75      0.71      0.73       154
# weighted avg       0.78      0.79      0.78       154
#
#
# Confusion Matrix:
#  [[96 11]
#  [22 25]]
#
# Testing Score:
#  78.57142857142857
#
# Mean Squared Error:
#  0.21428571428571427
#
# R2 score is:
#  -0.01053887452773905
#
# best params:  {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#
# accuracy score 78.57142857142857

# %%
#Precision Recall Curve for Support Vector 

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
from matplotlib import pyplot

# predict probabilities
SVprobs = SVmodel.predict_proba(X_test)
# keep probabilities for the positive outcome only
SVprobs = SVprobs[:, 1]
# predict class values
yhat = SVmodel.predict(X_test)
# calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_test, SVprobs)
# calculate F1 score
f1 = f1_score(y_test, yhat)
# calculate precision-recall AUC
auc = auc(recall, precision)
# calculate average precision score
ap = average_precision_score(y_test, SVprobs)
print('Support Vector: f1=%.3f auc=%.3f ap=%.3f' % (f1, auc, ap))
# plot no skill
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
# plot the precision-recall curve for the model
plt.plot(recall, precision, marker='.',label='Support Vector')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Support Vector: f1=0.602 auc=0.718 ap=0.721

# %% [markdown]
# #### Gradient Boosting Algorithm

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBmodel=GradientBoostingClassifier()
GBmodel.fit(X_train,y_train)
y_pred=GBmodel.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("\nConfusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("\nTesting Score:\n",GBmodel.score(X_test,y_test)*100)
print("\nMean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("\nR2 score is:\n",r2_score(y_test,y_pred))
print("\nbest params: ", GBmodel.get_params())
print('\naccuracy score',accuracy_score(y_test,y_pred)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       107
#            1       0.64      0.60      0.62        47
#
#     accuracy                           0.77       154
#    macro avg       0.73      0.72      0.73       154
# weighted avg       0.77      0.77      0.77       154
#
#
# Confusion Matrix:
#  [[91 16]
#  [19 28]]
#
# Testing Score:
#  77.27272727272727
#
# Mean Squared Error:
#  0.22727272727272727
#
# R2 score is:
#  -0.07178365480214755
#
# ...

# %%
#Precision Recall Curve for Gradient Boosting

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
from matplotlib import pyplot

# predict probabilities
GBprobs = GBmodel.predict_proba(X_test)
# keep probabilities for the positive outcome only
GBprobs = GBprobs[:, 1]
# predict class values
yhat = GBmodel.predict(X_test)
# calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_test, GBprobs)
# calculate F1 score
f1 = f1_score(y_test, yhat)
# calculate precision-recall AUC
auc = auc(recall, precision)
# calculate average precision score
ap = average_precision_score(y_test, GBprobs)
print('Gradient Boosting: f1=%.3f auc=%.3f ap=%.3f' % (f1, auc, ap))
# plot no skill
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
# plot the precision-recall curve for the model
plt.plot(recall, precision, marker='.',label='Gradient Boosting')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# Gradient Boosting: f1=0.615 auc=0.727 ap=0.730

# %% [markdown]
# #### XGBoost Classifier

# %%
from xgboost import XGBClassifier
XGBmodel=XGBClassifier(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,max_depth = 5, alpha = 10, n_estimators = 10)
XGBmodel.fit(X_train,y_train)
y_pred=XGBmodel.predict(X_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("\nConfusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("\nTesting Score:\n",XGBmodel.score(X_test,y_test)*100)
print("\nMean Squared Error:\n",mean_squared_error(y_test,y_pred))
print("\nR2 score is:\n",r2_score(y_test,y_pred))
print("\nbest params: ", XGBmodel.get_params())
print('\naccuracy score',accuracy_score(y_test,y_pred)*100)
# Out:
# [14:51:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/objective/regression_obj.cu:171: reg:linear is now deprecated in favor of reg:squarederror.
# Classification Report is:
#                precision    recall  f1-score   support
#
#            0       0.74      0.94      0.83       107
#            1       0.67      0.26      0.37        47
#
#     accuracy                           0.73       154
#    macro avg       0.70      0.60      0.60       154
# weighted avg       0.72      0.73      0.69       154
#
#
# Confusion Matrix:
#  [[101   6]
#  [ 35  12]]
#
# Testing Score:
#  73.37662337662337
#
# Mean Squared Error:
#  0.2662337662337662
#
# R2 score is:
#  -0.2555179956253728
#
# ...

# %%
#Precision Recall Curve for XGBoost

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
from matplotlib import pyplot

# predict probabilities
XGBprobs = XGBmodel.predict_proba(X_test)
# keep probabilities for the positive outcome only
XGBprobs = XGBprobs[:, 1]
# predict class values
yhat = XGBmodel.predict(X_test)
# calculate precision-recall curve
precision, recall, thresholds = precision_recall_curve(y_test, XGBprobs)
# calculate F1 score
f1 = f1_score(y_test, yhat)
# calculate precision-recall AUC
auc = auc(recall, precision)
# calculate average precision score
ap = average_precision_score(y_test, XGBprobs)
print('XGBoost: f1=%.3f auc=%.3f ap=%.3f' % (f1, auc, ap))
# plot no skill
no_skill = len(y_test[y_test==1]) / len(y_test)
pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
# plot the precision-recall curve for the model
plt.plot(recall, precision, marker='.',label='XGBoost')
# axis labels
pyplot.xlabel('Recall')
pyplot.ylabel('Precision')
# show the legend
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# XGBoost: f1=0.369 auc=0.517 ap=0.525

# %% [markdown]
# # Logistic Regression is performing best for the Diabetes dataset
